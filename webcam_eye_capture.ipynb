# %% [markdown]
# # 구글 드라이브 마운트
# - 저의 경우에는 '/content/drive'가 경로이지만 /gdrive/drive인 분들은 다시 dir를 입력하시면 됩니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 밑 부분은 강사님께서 올리신 코드와 유사합니다. javascript를 이용해 웹캠 연결하는 부분입니다.

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
# initialize the Haar Cascade face detection model
eye_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_eye.xml'))

# %%
# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %%
# !wget   http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2 # DOWNLOAD LINK
# !bunzip2 shape_predictor_68_face_landmarks.dat.bz2
# Out:
# --2022-07-31 11:34:31--  http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64040097 (61M)
# Saving to: ‘shape_predictor_68_face_landmarks.dat.bz2’
#
# shape_predictor_68_ 100%[===================>]  61.07M  27.5MB/s    in 2.2s
#
# 2022-07-31 11:34:34 (27.5 MB/s) - ‘shape_predictor_68_face_landmarks.dat.bz2’ saved [64040097/64040097]
#
# bunzip2: Output file shape_predictor_68_face_landmarks.dat already exists.

# %%
class Classifier:

    def classify(self, image):
        
        predicted = model.predict(np.expand_dims(image, axis=0))
        return np.argmax(predicted, axis=1)[0]

classifier = Classifier()

# %% [markdown]
# # 파일의 시작점과 파일을 저장하는 경로 지정
# - train/open 과 train/close 폴더를 미리 구글 드라이브에서 생성해서 사용하세요

# %%
open_max_index = 1263 # 눈 떠있는 파일의 시작점
close_max_index = 1000 # 눈을 감고 있는 파일의 시작점
open_file_dir = "/content/drive/MyDrive/2022_IOT_영상인식과정/data/train/open" 
close_file_dir = "/content/drive/MyDrive/2022_IOT_영상인식과정/data/train/close"

# %% [markdown]
# # 비디오를 캡처하고 캡처한 이미지의 눈 부분을 crop 한 다음 jpg 파일로 저장하는 부분
# - 한 번 실행할 때 마다 왼쪽 눈과 오른 쪽 눈을 저장합니다.
# - 캡처된 사진을 확인하고 눈을 떴으면 1을 입력하고 눈을 감았으면 0을 입력하고 enter를 입력하면 됩니다.
# - 윙크를 하시면 0이나 1과 다른 숫자 아무거나 입력해서 넘어가도록 하면 됩니다.
# - 만약 런타임이 끊어지게 되면 변수가 저장이 되지 않을 수 있기 때문에 /train/open에 들어가서 가장 큰 숫자로 위의 open_max_index 변수를 변경해주시면 됩니다. (close 도 마찬가지로 해주시면 됩니다.)
# - 밑에 os.chdir("/content")는 'shape_predictor_68_face_landmarks.dat'가 있는 디렉토리로 이동하기 위한 것으로 만약 코드를 재실행하게 되면 생기는 error를 방지하기 위해 만들었습니다. 따라서  다시 실행했을 때 error가 나오면 'shape_predictor_68_face_landmarks.dat'가 있는 디렉토리를 찾아서 변경해주시면 됩니다.

# %%
import cv2, dlib
import numpy as np
from imutils import face_utils
from keras.models import load_model
from google.colab.patches import cv2_imshow
import os


os.chdir("/content")
IMG_SIZE = (640, 480)

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

#model = load_model('/content/model_res50.h5')
#model.summary()
def crop_eye(img, eye_points):
  x1, y1 = np.amin(eye_points, axis=0)
  x2, y2 = np.amax(eye_points, axis=0)
  cx, cy = (x1 + x2) / 2, (y1 + y2) / 2

  w = (x2 - x1) * 1.2
  h = w * IMG_SIZE[1] / IMG_SIZE[0]

  margin_x, margin_y = w / 2, h / 2

  min_x, min_y = int(cx - margin_x), int(cy - margin_y)
  max_x, max_y = int(cx + margin_x), int(cy + margin_y)

  eye_rect = np.rint([min_x, min_y, max_x, max_y]).astype(np.int)

  eye_img = gray[eye_rect[1]:eye_rect[3], eye_rect[0]:eye_rect[2]]

  return eye_img, eye_rect
# start streaming video from webcam
video_stream()
# label for video
label_html = 'Capturing...'
# initialze bounding box to empty
bbox = ''
count = 0 
class_name = {0: "open", 1 :"close"}
while True:
    
    js_reply = video_frame(label_html, bbox)
    
    if not js_reply:
        break
    img = js_to_image(js_reply["img"])  
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    faces = detector(gray)
    

    for face in faces:
        shapes = predictor(gray, face) 
        shapes = face_utils.shape_to_np(shapes)

        eye_img_l, eye_rect_l = crop_eye(gray, eye_points=shapes[36:42])
        eye_img_r, eye_rect_r = crop_eye(gray, eye_points=shapes[42:48])

        eye_img_l = cv2.resize(eye_img_l, dsize=(34,26))
        eye_img_r = cv2.resize(eye_img_r, dsize=(34,26))
       # eye_img_r = cv2.flip(eye_img_r, flipCode=1)

        cv2_imshow( eye_img_l) # 이 이미지를 확인해서 눈을 뜬 건지 감은 건지 판단합니다. 
        cv2_imshow( eye_img_r)
        state = input("open: 1 or close: 0")
        state = int(state)
       # print(type(state))
        if state == 1: # 눈을 떴을 때 
            open_max_index += 1 # 저장하는 파일의 이름이 겹치지 않도록 index에 1을 더하는 부분입니다. 
            file_name = 'kw_image'+str(open_max_index)+'.jpg' # 저장될 파일이름을 정의하는 부분입니다. 
            os.chdir(open_file_dir) # 저장할 파일 이름으로 디렉토리를 이동하는 부분입니다. 
            cv2.imwrite(file_name, eye_img_l) # 파일을 현재 디렉토리에 저장하는 부분입니다. (왼쪽 눈)
            open_max_index += 1  # 아래는 오른쪽 눈에 대해 반복합니다. 
            file_name = 'kw_image'+str(open_max_index)+'.jpg'
            cv2.imwrite(file_name, eye_img_r)           
        elif state == 0: # 눈을 감았을 때 위의 코드와 유사한 작업이 반복됩니다. 
            close_max_index += 1
            file_name = 'kw_image'+str(close_max_index)+'.jpg'
            os.chdir(close_file_dir)
            cv2.imwrite(file_name, eye_img_l)
            close_max_index += 1
            file_name = 'kw_image'+str(close_max_index)+'.jpg'
            cv2.imwrite(file_name, eye_img_r)
        else: 
          print("error") # 0이나 1을 입력하지 않았을 때 error가 나오는 부분입니다. 
       # eye_img_l3 = np.reshape(eye_img_l ,(34,26) )
     #   eye_img_r3 = np.reshape(eye_img_r ,(34,26))
     #   r = model.predict(preprocess_input(eye_img_r3))
      #  l = model.predict(preprocess_input(eye_img_l3))
       # print(int(r[0]))
        #print(int(l[0]))
        
        #if (int(r[0])==1 or int(l[0]) == 1) : category = 0
        #if (int(r[0])==0 and int(l[0]) == 0) : category = 1

        #abel_html = class_name[category]
    # convert JS response to OpenCV Image
    

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# <PIL.Image.Image image mode=L size=34x26 at 0x7FBA1256FED0>
# <PIL.Image.Image image mode=L size=34x26 at 0x7FBA0FCFE990>
# open: 1 or close: 00
# <PIL.Image.Image image mode=L size=34x26 at 0x7FBA0FCF65D0>
# <PIL.Image.Image image mode=L size=34x26 at 0x7FBA0FCFEA10>
# open: 1 or close: 00
# <PIL.Image.Image image mode=L size=34x26 at 0x7FBA0FCFEA90>
# <PIL.Image.Image image mode=L size=34x26 at 0x7FBA0FCFE890>
# ...
